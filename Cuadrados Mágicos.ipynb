# %%
# DEFINICIÓN DE FUNCIONES 

import time

def tablero():
    print('\n     ' + '\033[4m ' + 'A' + ' \033[0m '
          + '\033[4m '+ 'B' + ' \033[0m '
          + '\033[4m ' + 'C' + ' \033[0m '
          + '\033[4m ' + 'D' + ' \033[0m '
          + '\033[92m' + '\033[1m' + '27*' + '\033[0m'
          + '\n   1| ' + '\033[94m' + '\033[1m' + str(casillas_iniciales['1A']) + '\033[0m'
          + '\033[1m   ' + str(casillas_jugables['1B'])
          + '\033[94m   ' + str(casillas_iniciales['1C'] ) + '\033[0m'
          + '\033[1m   ' +str(casillas_jugables['1D'] ) + '\033[0m'
          + ' |' + '\033[92m' + '\033[1m' + '22' + '\033[0m'
          + '\n   2| ' + '\033[94m' + '\033[1m' + str(casillas_iniciales['2A']) + '\033[0m'
          + '\033[1m   ' + str(casillas_jugables['2B'])
          + '\033[94m   ' + str(casillas_iniciales['2C']) + '\033[0m'
          + '\033[1m   ' + str(casillas_jugables['2D']) + '\033[0m'
          + ' |' + '\033[92m' + '\033[1m' + '24' + '\033[0m'
         http://localhost:8889/notebooks/Cuadrados%20M%C3%A1gicos.ipynb# + '\n   3| ' + '\033[1m' + str(casillas_jugables['3A'])
          + '\033[94m   ' + str(casillas_iniciales['3B']) + '\033[0m'
          + '\033[1m   ' + str(casillas_jugables['3C'])
          + '\033[94m   ' + str(casillas_iniciales['3D']) + '\033[0m'
          +' |'+'\033[92m'+'\033[1m'+'21'+'\033[0m'
          + '\n   4| ' + '\033[1m' + str(casillas_jugables['4A'])
          + '\033[94m   ' + str(casillas_iniciales['4B']) + '\033[0m'
          + '\033[1m   ' + str(casillas_jugables['4C'])
          + '   ' + str(casillas_jugables['4D']) + '\033[0m'
          + ' |\033[92m' + '\033[1m' + '23\n     25  29  18  18  19*' + '\033[0m')
    
def elegir_casilla():
    global casilla_elegida
    casilla_elegida = input('\nMarque la casilla que desea seleccionar (formato: fila/columna, ej: 4C): ')
    if casilla_elegida.upper() not in casillas_jugables.keys() and casilla_elegida.upper() not in casillas_iniciales.keys():
        casilla_elegida = ''
        print('\033[91m' + '\033[1m' + '\nLa casilla marcada no existe' + '\033[0m')
        time.sleep(3)
    elif casilla_elegida.upper() in casillas_iniciales.keys():
        casilla_elegida = ''
        print('\033[91m' + '\033[1m' + '\nNo puedes cambiar una casilla inicial' + '\033[0m')
        time.sleep(3)
    return(casilla_elegida.upper())

def vaciar_casilla():
    global casillas_jugables, permiso1, permiso2
    if type(casillas_jugables[casilla_elegida]) == int:
        respuesta = input('\n¿Desea vaciar la casilla seleccionada? (formato respuesta: Si o No)\n')
        if respuesta.lower() == 'si':
            casillas_jugables[casilla_elegida] = ' '
            permiso1 = True
            permiso2 = True
        elif respuesta.lower() == 'no':
            permiso1 = True
        else:
            print('\033[91m' + '\033[1m' + '\nDebes responder \"Si\" o \"No\"' + '\033[0m')
            time.sleep(3)
            permiso1 = False
    else:
        permiso1 = True
            
def asignar_valor():
    global casillas_jugables, permiso2
    try:
        casillas_jugables[casilla_elegida] = int(input('\nIntroduzca el valor que quiere poner '
                                                           + 'en la casilla seleccionada (números enteros del 0 al 9): '))
        if casillas_jugables[casilla_elegida] < 0 or casillas_jugables[casilla_elegida] > 9:
            casillas_jugables[casilla_elegida] = ' '
            permiso2 = False
            print('\033[91m' + '\033[1m' + '\nEl valor introducido no está permitido' + '\033[0m')
            time.sleep(3)
        else:
            permiso2 = True
            
    except ValueError:
        casillas_jugables[casilla_elegida] = ' '
        permiso2 = False
        print('\033[91m' + '\033[1m' + '\nDebes introducir un número del 0 al 9' + '\033[0m')
        time.sleep(3)
    return(casillas_jugables[casilla_elegida])

def comprobacion():
    global casillas_jugables, juego_terminado
    suma_fila1 = 0
    check_fila1 = False
    fila1 = {'1A': casillas_iniciales['1A'], '1B': casillas_jugables['1B'], '1C': casillas_iniciales['1C'], '1D': casillas_jugables['1D']}
    for valor in fila1.values():
        try:
            suma_fila1 += valor
        except (TypeError, ValueError):
            continue
    suma_fila2 = 0
    check_fila2 = False
    fila2 = {'2A': casillas_iniciales['2A'], '2B': casillas_jugables['2B'], '2C': casillas_iniciales['2C'], '2D': casillas_jugables['2D']}
    for valor in fila2.values():
        try:
            suma_fila2 += int(valor)
        except (TypeError, ValueError):
            continue
    suma_fila3 = 0
    check_fila3 = False
    fila3 = {'3A': casillas_jugables['3A'], '3B': casillas_iniciales['3B'], '3C': casillas_jugables['3C'], '3D': casillas_iniciales['3D']}
    for valor in fila3.values():
        try:
            suma_fila3 += valor
        except (TypeError, ValueError):
            continue
    suma_fila4 = 0
    check_fila4 = False
    fila4 = {'4A': casillas_jugables['4A'], '4B': casillas_iniciales['4B'], '4C': casillas_jugables['4C'], '4D': casillas_jugables['4D']}
    for valor in fila4.values():
        try:
            suma_fila4 += valor
        except (TypeError, ValueError):
            continue
    suma_columnaA = 0
    check_columnaA = False
    columnaA = {'1A': casillas_iniciales['1A'], '2A': casillas_iniciales['2A'], '3A': casillas_jugables['3A'], '4A': casillas_jugables['4A']}
    for valor in columnaA.values():
        try:
            suma_columnaA += valor
        except (TypeError, ValueError):
            continue
    suma_columnaB = 0
    check_columnaB = False
    columnaB = {'1B': casillas_jugables['1B'], '2B': casillas_jugables['2B'], '3B': casillas_iniciales['3B'], '4B': casillas_iniciales['4B']}
    for valor in columnaB.values():
        try:
            suma_columnaB += valor
        except (TypeError, ValueError):
            continue
    suma_columnaC = 0
    check_columnaC = False
    columnaC = {'1C': casillas_iniciales['1C'], '2C': casillas_iniciales['2C'], '3C': casillas_jugables['3C'], '4C': casillas_jugables['4C']}
    for valor in columnaC.values():
        try:
            suma_columnaC += valor
        except (TypeError, ValueError):
            continue
    suma_columnaD = 0
    check_columnaD = False
    columnaD = {'1D': casillas_jugables['1D'], '2D': casillas_jugables['2D'], '3D': casillas_iniciales['3D'], '4D': casillas_jugables['4D']}
    for valor in columnaD.values():
        try:
            suma_columnaD += valor
        except (TypeError, ValueError):
            continue
    suma_diagonal_abajo = 0
    check_diagonal_abajo = False
    diagonal_abajo = {'1A': casillas_iniciales['1A'], '2B': casillas_jugables['2B'], '3C': casillas_jugables['3C'], '4D': casillas_jugables['4D']}
    for valor in diagonal_abajo.values():
        try:
            suma_diagonal_abajo += valor
        except (TypeError, ValueError):
            continue
    suma_diagonal_arriba = 0
    check_diagonal_arriba = False
    diagonal_arriba = {'4A': casillas_jugables['4A'], '3B': casillas_iniciales['3B'], '2C': casillas_iniciales['2C'], '1D': casillas_jugables['1D']}
    for valor in diagonal_arriba.values():
        try:
            suma_diagonal_arriba += valor
        except (TypeError, ValueError):
            continue
    if suma_fila1 > 22:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida 
              + '\" hace que el sumatorio de la fila 1 sea mayor que 22' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(fila1['1A']) == int and type(fila1['1B']) == int and type(fila1['1C']) == int and type(fila1['1D']) == int and suma_fila1 < 22:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la fila 1 sea menor que 22' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_fila1 == 22:
        check_fila1 = True
    if suma_fila2 > 24:
        print('\033[91m' + '\033[1m' 
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida]) 
              + '\" en la casilla \"'+ casilla_elegida
              + '\" hace que el sumatorio de la fila 2 sea mayor que 24' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(fila2['2A']) == int and type(fila2['2B']) == int and type(fila2['2C']) == int and type(fila2['2D']) == int and suma_fila2 < 24:
        print('\033[91m' + '\033[1m'
        + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
        + '\" en la casilla \"' + casilla_elegida 
        + '\" hace que el sumatorio de la fila 2 sea menor que 24' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_fila2 == 24:
        check_fila2 = True
    if suma_fila3 > 21:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la fila 3 sea mayor que 21' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(fila3['3A']) == int and type(fila3['3B']) == int and type(fila3['3C']) == int and type(fila3['3D']) == int and suma_fila3 < 21:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la fila 3 sea menor que 21' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_fila3 == 21:
        check_fila3 = True
    if suma_fila4 > 23:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la fila 4 sea mayor que 23' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(fila4['4A']) == int and type(fila4['4B']) == int and type(fila4['4C']) == int and type(fila4['4D']) == int and suma_fila4 < 23:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la fila 4 sea menor que 23' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_fila4 == 23:
        check_fila4 = True
    if suma_columnaA > 25:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la columna A sea mayor que 25' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(columnaA['1A']) == int and type(columnaA['2A']) == int and type(columnaA['3A']) == int and type(columnaA['4A']) == int and suma_columnaA < 25:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la columna A sea menor que 25' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_columnaA == 25:
        check_columnaA = True
    if suma_columnaB > 29:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la columna B sea mayor que 29' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(columnaB['1B']) == int and type(columnaB['2B']) == int and type(columnaB['3B']) == int and type(columnaB['4B']) == int and suma_columnaB < 29:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la columna B sea menor que 29' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_columnaB == 29:
        check_columnaB = True
    if suma_columnaC > 18:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la columna C sea mayor que 18' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(columnaC['1C']) == int and type(columnaC['2C']) == int and type(columnaC['3C']) == int and type(columnaC['4C']) == int and suma_columnaC < 18:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la columna C sea menor que 18' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_columnaC == 18:
        check_columnaC = True
    if suma_columnaD > 18:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la columna D sea mayor que 18' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(columnaD['1D']) == int and type(columnaD['2D']) == int and type(columnaD['3D']) == int and type(columnaD['4D']) == int and suma_columnaD < 18:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la columna D sea menor que 18' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_columnaD == 18:
        check_columnaD = True
    if suma_diagonal_abajo > 19:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la diagonal hacia abajo sea mayor que 19' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(diagonal_abajo['1A']) == int and type(diagonal_abajo['2B']) == int and type(diagonal_abajo['3C']) == int and type(diagonal_abajo['4D']) == int and suma_diagonal_abajo < 19:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la diagonal hacia abajo sea menor que 19' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_diagonal_abajo == 19:
        check_diagonal_abajo = True
    if suma_diagonal_arriba > 27:
        print('\033[91m' + '\033[1m'
              + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
              + '\" en la casilla \"' + casilla_elegida
              + '\" hace que el sumatorio de la diagonal hacia arriba sea mayor que 27' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif type(diagonal_arriba['4A']) == int and type(diagonal_arriba['3B']) == int and type(diagonal_arriba['2C']) == int and type(diagonal_arriba['1D']) == int and suma_diagonal_arriba < 27:
        print('\033[91m' + '\033[1m'
          + '\nEl valor \"' + str(casillas_jugables[casilla_elegida])
          + '\" en la casilla \"' + casilla_elegida 
          + '\" hace que el sumatorio de la diagonal hacia arriba sea menor que 27' + '\033[0m')
        time.sleep(3)
        casillas_jugables[casilla_elegida] = ' '
    elif suma_diagonal_arriba == 27:
        check_diagonal_arriba = True
        
    if (check_fila1 == True and check_fila2 == True and check_fila3 == True and check_fila4 == True
        and check_columnaA == True and check_columnaB == True and check_columnaC == True
        and check_columnaD == True and check_diagonal_abajo == True and check_diagonal_arriba == True):
        juego_terminado = True
        
# DECLARACIÓN DE VARIABLES GLOBALES Y ASIGNACIÓN DE VALORES INICIALES
            
casillas_iniciales = {'1A': 4, '1C': 3, '2A': 8, '2C': 7, '3B': 9, '3D': 2, '4B': 5}
casillas_jugables = {'1B': ' ', '1D': ' ', '2B': ' ', '2D': ' ', '3A': ' ', '3C': ' ', '4A': ' ', '4C': ' ', '4D': ' '}
casilla_elegida = ''
juego_terminado = False
permiso1 = False
permiso2 = False

# PROGRAMA PRINCIPAL

print('\033[1m'+'\n !Bienvenido/a a Cuadrados Mágicos! A continuación se le mostrará un resumen de las reglas del juego:'
      +'\n\n  - El objetivo del juego es completar las casillas vacias de la cuadricula mostrada con valores numericos del '
      +'\n  0 al 9 de tal forma que la suma de los valores de cada fila, columna y diagonal den como resultado los valores '
      +'\n  resaltados en verde al final de cada una de ellas (en el caso de las diagonales vienen diferenciados por un \"*\").'
      +'\n\n  - La secuencia de juego es:'
      +'\n\n          1º : El jugador debe indicar la casilla que quiere seleccionar, introduciendo la fila seguida de la columna'
      +'\n               (ejemplo: 4C). Como es lógico, no está permitido cambiar los valores de las casillas iniciales. Para evitar'
      +'\n               confusiones, estos estarán resaltados en azul'
      +'\n\n          2º : Una vez escogida una casilla permitida, se debe asignar un valor del 0 al 9 a la misma. Este no puede'
      +'\n               entrar en conflicto con ningún sumatorio. De ser asi, se reseteará la casilla en cuestión. Cuando el jugador'
      +'\n               haya escogido una casilla que ya tenga un número previamente asignado por él, se le pregutará si desea'
      +'\n               vaciar la misma, con el propósito de facilitarle rectificaciones. En este caso, se debe responder \"Si\"'
      +'\n               o \"No\". Si la respuesta es \"Si\", la casilla se reseteará y el jugador volverá al 1º paso. Si la respuesta'
      +'\n               \"No\", el jugador podrá sobreescribir el valor de esa casilla.'
      +'\n\n          3º : Una vez que no haya casillas vacias, si ningún sumatorio entra en conflicto con el valor correspondiente,'
      +'\n               habrá ganado la partida. Mientras esto no sea así, se seguirá repitiendo la secuencia anterior.'
      +'\n\n Esperamos que se lo pase genial, ¡Buena suerte!'+'\033[0m')
tablero()
while juego_terminado == False:
    while casilla_elegida not in casillas_jugables.keys():
        casilla_elegida = elegir_casilla()
        permiso1 = False
        permiso2 = False
    while permiso1 == False:
        vaciar_casilla()
    while permiso2 == False:
        casillas_jugables[casilla_elegida] = asignar_valor()
    comprobacion()
    casilla_elegida = None
    tablero()
print('\033[1m'+ '\n¡Enhorabuena, has completado el juego!'+'\033[0m')
# Out:
#  !Bienvenido/a a Cuadrados Mágicos! A continuación se le mostrará un resumen de las reglas del juego:
#
#   - El objetivo del juego es completar las casillas vacias de la cuadricula mostrada con valores numericos del
#   0 al 9 de tal forma que la suma de los valores de cada fila, columna y diagonal den como resultado los valores
#   resaltados en verde al final de cada una de ellas (en el caso de las diagonales vienen diferenciados por un "*").
#
#   - La secuencia de juego es:
#
#           1º : El jugador debe indicar la casilla que quiere seleccionar, introduciendo la fila seguida de la columna
#                (ejemplo: 4C). Como es lógico, no está permitido cambiar los valores de las casillas iniciales. Para evitar
#                confusiones, estos estarán resaltados en azul
#
#           2º : Una vez escogida una casilla permitida, se debe asignar un valor del 0 al 9 a la misma. Este no puede
# ...
